# %%
import pandas as pd

df_train = pd.read_csv('../data/raw/train.csv')

# %%
df_train.nunique()
# Out:
# ID                        28800
# dri_score                    11
# psych_disturb                 3
# cyto_score                    7
# diabetes                      3
# hla_match_c_high              3
# hla_high_res_8                7
# tbi_status                    8
# arrhythmia                    3
# hla_low_res_6                 5
# graft_type                    2
# vent_hist                     2
# renal_issue                   3
# pulm_severe                   3
# prim_disease_hct             18
# hla_high_res_6                6
# cmv_status                    4
# hla_high_res_10               8
# hla_match_dqb1_high           3
# tce_imm_match                 8
# hla_nmdp_6                    5
# hla_match_c_low               3
# rituximab                     2
# hla_match_drb1_low            2
# hla_match_dqb1_low            3
# prod_type                     2
# cyto_score_detail             5
# conditioning_intensity        6
# ethnicity                     3
# year_hct                     13
# obesity                       3
# mrd_hct                       2
# in_vivo_tcd                   2
# tce_match                     4
# hla_match_a_high              3
# hepatic_severe                3
# donor_age                 20909
# prior_tumor                   3
# hla_match_b_low               3
# peptic_ulcer                  3
# age_at_hct                22168
# hla_match_a_low               3
# gvhd_proph                   17
# rheum_issue                   3
# sex_match                     4
# hla_match_b_high              3
# race_group                    6
# comorbidity_score            11
# karnofsky_score               7
# hepatic_mild                  3
# tce_div_match                 4
# donor_related                 3
# melphalan_dose                2
# hla_low_res_8                 7
# cardiac                       3
# hla_match_drb1_high           3
# pulm_moderate                 3
# hla_low_res_10                7
# efs                           2
# efs_time                  19208
# dtype: int64

# %%
df_train['efs_time'].plot(kind='hist', bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# plot hla_match_drb1_low vs efs
df_train.plot.scatter(x='hla_match_drb1_high', y='efs', c='efs')
# Out:
# <Axes: xlabel='hla_match_drb1_high', ylabel='efs'>

# %%
# target variable
df_train['efs'].value_counts()
# Out:
# efs
# 1.0    15532
# 0.0    13268
# Name: count, dtype: int64

# %%
# plot distribution of numerical features
import matplotlib.pyplot as plt
df_train.hist(bins=50, figsize=(20, 15))
plt.show()
